# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Nicoleta Roman
# - Alumno 2: Esteban Aspe
# - Alumno 3: Jelena Duric
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/4oNHlRFEd71HXp4](https://drive.upm.es/s/4oNHlRFEd71HXp4)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Helicopter', 2: 'Small car', 3: 'Bus', 4: 'Truck', 5: 'Motorboat', 6: 'Fishing vessel', 7: 'Dump truck', 8: 'Excavator', 9: 'Building', 10: 'Storage tank', 11: 'Shipping container'}

# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (25.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from rasterio) (3.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24->rasterio) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.24->rasterio) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.24->rasterio) (2024.2.0)
# Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 83.6 MB/s eta 0:00:00:00:0100:01
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.4.3

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('/kaggle/input/deep-learning/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json
# Load database

json_file = '/kaggle/input/deep-learning/xview_recognition/xview_ann_train.json' 
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Helicopter': 70, 'Small car': 4290, 'Bus': 2155, 'Truck': 2746, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 4689, 'Storage tank': 1469, 'Shipping container': 1523}

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

labels = [image.objects[0].category for image in anns]
anns_train, anns_valid = train_test_split(anns, test_size=0.12, random_state=1, shuffle=True, stratify=labels)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 18811
# Number of validation images: 2566

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, LeakyReLU, Input
from tensorflow.keras.optimizers import Adam
print('Load model')


def build_model():
    model = Sequential()
    model.add(Input(shape=(224, 224, 3)))  # Use Input layer instead of input_shape in Flatten
    model.add(Flatten())
   
    model.add(Dense(1024))  
    model.add(LeakyReLU(negative_slope=0.01))  # Second hidden layer with LeakyReLU

    model.add(Dense(512))  
    model.add(LeakyReLU(negative_slope=0.01))

    model.add(Dense(256))  
    model.add(LeakyReLU(negative_slope=0.01))
    
    model.add(Dense(len(categories)))
    model.add(Activation('softmax'))
   # Learning rate is changed to 0.001
    opt = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

strategy = tf.distribute.MirroredStrategy() # Strategy for multi gpu usage
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# buiding a model inside the strategy scope
with strategy.scope():
    multi_gpu_model = build_model()
    
multi_gpu_model.summary()
# Out:
# Load model
# Number of devices: 1
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 150528)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │     154,141,696 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 12)                  │           3,084 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 12)                  │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 154,800,908 (590.52 MB)
#  Trainable params: 154,800,908 (590.52 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=10, verbose=1)
early_stop = EarlyStopping('val_accuracy', patience=40, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
from sklearn.preprocessing import StandardScaler
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Compute mean & std from training images before defining the generator
train_images = np.array([load_geoimage(filename) for filename, _ in objs_train])
mean = np.mean(train_images, axis=(0,1,2))  # Compute mean per channel
std = np.std(train_images, axis=(0,1,2))  # Compute std per channel
print("mean",mean)
print("std",std)
def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                # Load image
                img = load_geoimage(filename).astype(np.float32)

                # Apply standardization
                img = (img - mean) / std  

                images.append(img)
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels
# Out:
# mean [69.31671926 57.07645186 49.67770869]
# std [51.84275139 44.94404335 41.23820328]

# %%
# Generators
batch_size = 128
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9464207674205256124
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16266690560
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 9336314400276085588
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
import math
import numpy as np

print('Training model')
epochs = 20
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)

with tf.device("/device:GPU:0"):
    h = multi_gpu_model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2239 - loss: 46.5661
# Epoch 1: val_accuracy improved from -inf to 0.27280, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 714s 5s/step - accuracy: 0.2241 - loss: 46.3936 - val_accuracy: 0.2728 - val_loss: 3.3823 - learning_rate: 0.0010
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 855ms/step - accuracy: 0.3318 - loss: 2.8389
# Epoch 2: val_accuracy improved from 0.27280 to 0.40725, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.3319 - loss: 2.8361 - val_accuracy: 0.4072 - val_loss: 1.9100 - learning_rate: 0.0010
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 793ms/step - accuracy: 0.4421 - loss: 1.6645
# Epoch 3: val_accuracy improved from 0.40725 to 0.48168, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 142s 971ms/step - accuracy: 0.4422 - loss: 1.6643 - val_accuracy: 0.4817 - val_loss: 1.5765 - learning_rate: 0.0010
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.5131 - loss: 1.4485
# Epoch 4: val_accuracy improved from 0.48168 to 0.52065, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 140s 962ms/step - accuracy: 0.5131 - loss: 1.4485 - val_accuracy: 0.5207 - val_loss: 1.4945 - learning_rate: 0.0010
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.5439 - loss: 1.3609
# Epoch 5: val_accuracy did not improve from 0.52065
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 115s 786ms/step - accuracy: 0.5439 - loss: 1.3609 - val_accuracy: 0.5207 - val_loss: 1.4528 - learning_rate: 0.0010
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5794 - loss: 1.2292
# Epoch 6: val_accuracy improved from 0.52065 to 0.53040, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.5794 - loss: 1.2294 - val_accuracy: 0.5304 - val_loss: 1.4739 - learning_rate: 0.0010
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.5869 - loss: 1.1906
# Epoch 7: val_accuracy did not improve from 0.53040
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 109s 745ms/step - accuracy: 0.5869 - loss: 1.1907 - val_accuracy: 0.5300 - val_loss: 1.3967 - learning_rate: 0.0010
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6193 - loss: 1.1072
# Epoch 8: val_accuracy improved from 0.53040 to 0.54988, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.6192 - loss: 1.1073 - val_accuracy: 0.5499 - val_loss: 1.4323 - learning_rate: 0.0010
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 909ms/step - accuracy: 0.6380 - loss: 1.0566
# Epoch 9: val_accuracy improved from 0.54988 to 0.56118, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - accuracy: 0.6380 - loss: 1.0567 - val_accuracy: 0.5612 - val_loss: 1.4209 - learning_rate: 0.0010
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.6495 - loss: 0.9989
# Epoch 10: val_accuracy did not improve from 0.56118
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 123s 840ms/step - accuracy: 0.6495 - loss: 0.9990 - val_accuracy: 0.5549 - val_loss: 1.4215 - learning_rate: 0.0010
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 826ms/step - accuracy: 0.6698 - loss: 0.9554
# Epoch 11: val_accuracy did not improve from 0.56118
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 122s 831ms/step - accuracy: 0.6698 - loss: 0.9557 - val_accuracy: 0.5234 - val_loss: 1.4973 - learning_rate: 0.0010
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 958ms/step - accuracy: 0.6779 - loss: 0.9356
# Epoch 12: val_accuracy did not improve from 0.56118
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 141s 963ms/step - accuracy: 0.6779 - loss: 0.9357 - val_accuracy: 0.5511 - val_loss: 1.4497 - learning_rate: 0.0010
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.6926 - loss: 0.8852
# Epoch 13: val_accuracy improved from 0.56118 to 0.56703, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 133s 910ms/step - accuracy: 0.6926 - loss: 0.8852 - val_accuracy: 0.5670 - val_loss: 1.4762 - learning_rate: 0.0010
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7227 - loss: 0.8037
# Epoch 14: val_accuracy improved from 0.56703 to 0.57599, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - accuracy: 0.7227 - loss: 0.8039 - val_accuracy: 0.5760 - val_loss: 1.5116 - learning_rate: 0.0010
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7342 - loss: 0.7824
# Epoch 15: val_accuracy did not improve from 0.57599
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.7341 - loss: 0.7827 - val_accuracy: 0.5616 - val_loss: 1.5338 - learning_rate: 0.0010
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - accuracy: 0.7301 - loss: 0.7734
# Epoch 16: val_accuracy did not improve from 0.57599
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 117s 798ms/step - accuracy: 0.7301 - loss: 0.7735 - val_accuracy: 0.5612 - val_loss: 1.5745 - learning_rate: 0.0010
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.7531 - loss: 0.7238
# Epoch 17: val_accuracy did not improve from 0.57599
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 118s 808ms/step - accuracy: 0.7531 - loss: 0.7241 - val_accuracy: 0.5491 - val_loss: 1.5992 - learning_rate: 0.0010
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.7528 - loss: 0.7177
# Epoch 18: val_accuracy did not improve from 0.57599
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 123s 838ms/step - accuracy: 0.7527 - loss: 0.7179 - val_accuracy: 0.5452 - val_loss: 1.7387 - learning_rate: 0.0010
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 786ms/step - accuracy: 0.7548 - loss: 0.7161
# Epoch 19: val_accuracy improved from 0.57599 to 0.57989, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 130s 890ms/step - accuracy: 0.7548 - loss: 0.7162 - val_accuracy: 0.5799 - val_loss: 1.7342 - learning_rate: 0.0010
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7800 - loss: 0.6360
# Epoch 20: val_accuracy did not improve from 0.57989
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.7800 - loss: 0.6362 - val_accuracy: 0.5569 - val_loss: 1.7791 - learning_rate: 0.0010
# Best validation model: epoch 19  - val_accuracy 0.5798909068107605

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.savefig("/kaggle/working/confusion_matrix.png", format="png", bbox_inches="tight")
    plt.close()

# %%
import numpy as np
model = multi_gpu_model
multi_gpu_model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename).astype(np.float32)
    image = (image - mean) / std 
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)
results = h.history

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 10))

# Plot Accuracy
axes[0].plot(results["accuracy"], label="Training Accuracy", color="blue")
axes[0].plot(results["val_accuracy"], label="Validation Accuracy", color="green")
axes[0].set_ylabel("Accuracy")
axes[0].set_title("Accuracy Over Epochs")
axes[0].legend()
axes[0].grid(True)
axes[0].set_ylim(0, 1)  # Normalize y-axis for accuracy (0-1 range)

# Plot Loss
axes[1].plot(results["loss"], label="Training Loss", color="red")
axes[1].plot(results["val_loss"], label="Validation Loss", color="orange")
axes[1].set_ylabel("Loss")
axes[1].set_title("Loss Over Epochs")
axes[1].legend()
axes[1].grid(True)
axes[1].set_ylim(0, max(max(results["loss"]), max(results["val_loss"])) * 1.1)  # Normalize loss y-axis

plt.xlabel("Epochs")
plt.tight_layout()

plt.savefig("/kaggle/working/plot.png", format="png", bbox_inches="tight")
plt.close()
# Out:
# <ipython-input-15-dedca14cfdc5>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 35.074%
# Mean Recall: 27.371%
# Mean Precision: 27.934%
# > Cargo plane: Recall: 55.263% Precision: 29.371% Specificity: 95.944% Dice: 38.356%
# > Helicopter: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Small car: Recall: 46.214% Precision: 57.488% Specificity: 91.419% Dice: 51.238%
# > Bus: Recall: 8.494% Precision: 41.509% Specificity: 98.656% Dice: 14.103%
# > Truck: Recall: 19.394% Precision: 17.729% Specificity: 86.717% Dice: 18.524%
# > Motorboat: Recall: 25.781% Precision: 44.595% Specificity: 98.318% Dice: 32.673%
# > Fishing vessel: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Dump truck: Recall: 64.865% Precision: 16.189% Specificity: 79.446% Dice: 25.911%
# > Excavator: Recall: 21.053% Precision: 23.529% Specificity: 97.369% Dice: 22.222%
# > Building: Recall: 59.680% Precision: 50.986% Specificity: 83.874% Dice: 54.992%
# > Storage tank: Recall: 24.432% Precision: 26.543% Specificity: 95.021% Dice: 25.444%
# > Shipping container: Recall: 3.279% Precision: 27.273% Specificity: 99.329% Dice: 5.854%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/deep-learning/xview_recognition/xview_test'):
    for filename in filenames:
        image = GenericImage('xview_test/'+'/'+filename)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2635

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename).astype(np.float32)
    image = (image - mean) / std
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("/kaggle/working/prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
