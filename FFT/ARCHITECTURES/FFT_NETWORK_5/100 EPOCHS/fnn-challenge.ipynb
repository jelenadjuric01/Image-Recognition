# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1:
# - Alumno 2:
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/4oNHlRFEd71HXp4](https://drive.upm.es/s/4oNHlRFEd71HXp4)

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
categories = {0: 'Cargo plane', 1: 'Helicopter', 2: 'Small car', 3: 'Bus', 4: 'Truck', 5: 'Motorboat', 6: 'Fishing vessel', 7: 'Dump truck', 8: 'Excavator', 9: 'Building', 10: 'Storage tank', 11: 'Shipping container'}

# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (25.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from rasterio) (3.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24->rasterio) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.24->rasterio) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.24->rasterio) (2024.2.0)
# Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 83.9 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.4.3

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('/kaggle/input/deeplearning/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json
# Load database

json_file = '/kaggle/input/deeplearning/xview_recognition/xview_ann_train.json' 
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Helicopter': 70, 'Small car': 4290, 'Bus': 2155, 'Truck': 2746, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 4689, 'Storage tank': 1469, 'Shipping container': 1523}

# %%
from sklearn.model_selection import train_test_split

labels = [image.objects[0].category for image in anns]
anns_train, anns_valid = train_test_split(anns, test_size=0.12, random_state=1, shuffle=True, stratify=labels)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 18811
# Number of validation images: 2566

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, LeakyReLU, ReLU
from tensorflow.keras.optimizers import Adam

print('Load model')
model = Sequential()
model.add(Flatten(input_shape=(224, 224, 3)))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(1024))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(512))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(256))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(len(categories)))
model.add(Activation('softmax'))
model.summary()
# Out:
# Load model
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 150528)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 150528)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │     154,141,696 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)            │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 12)                  │           1,548 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 12)                  │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 154,832,268 (590.64 MB)
#  Trainable params: 154,832,268 (590.64 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import Adam

# Learning rate is changed to 0.001
opt = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from time import time
from tensorflow.keras.callbacks import TensorBoard
tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))
# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=10, verbose=1)
early_stop = EarlyStopping('val_accuracy', patience=40, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate, tensorboard]

# %%
def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                # Load image
                images.append(load_geoimage(filename))
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 128
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)

with tf.device("/device:GPU:0"):
    h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.1303 - loss: 9262.5166
# Epoch 1: val_accuracy improved from -inf to 0.14108, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 791s 5s/step - accuracy: 0.1304 - loss: 9230.7061 - val_accuracy: 0.1411 - val_loss: 433.2946 - learning_rate: 0.0010
# Epoch 2/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - accuracy: 0.1416 - loss: 664.7787
# Epoch 2: val_accuracy did not improve from 0.14108
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 117s 801ms/step - accuracy: 0.1416 - loss: 663.5394 - val_accuracy: 0.0717 - val_loss: 419.8128 - learning_rate: 0.0010
# Epoch 3/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.1371 - loss: 275.4209
# Epoch 3: val_accuracy did not improve from 0.14108
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 95s 648ms/step - accuracy: 0.1372 - loss: 274.8387 - val_accuracy: 0.0514 - val_loss: 260.4091 - learning_rate: 0.0010
# Epoch 4/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 622ms/step - accuracy: 0.1617 - loss: 125.3596
# Epoch 4: val_accuracy did not improve from 0.14108
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 100s 687ms/step - accuracy: 0.1617 - loss: 125.0890 - val_accuracy: 0.1411 - val_loss: 48.2929 - learning_rate: 0.0010
# Epoch 5/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.2206 - loss: 40.5321
# Epoch 5: val_accuracy improved from 0.14108 to 0.18823, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 102s 699ms/step - accuracy: 0.2206 - loss: 40.5319 - val_accuracy: 0.1882 - val_loss: 16.7147 - learning_rate: 0.0010
# Epoch 6/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 823ms/step - accuracy: 0.2223 - loss: 32.1626
# Epoch 6: val_accuracy did not improve from 0.18823
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 121s 828ms/step - accuracy: 0.2223 - loss: 32.2145 - val_accuracy: 0.1450 - val_loss: 28.1045 - learning_rate: 0.0010
# Epoch 7/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.2222 - loss: 39.4720
# Epoch 7: val_accuracy improved from 0.18823 to 0.19719, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 98s 672ms/step - accuracy: 0.2222 - loss: 39.5290 - val_accuracy: 0.1972 - val_loss: 18.6192 - learning_rate: 0.0010
# Epoch 8/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.2258 - loss: 61.9123
# Epoch 8: val_accuracy improved from 0.19719 to 0.20655, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 87s 597ms/step - accuracy: 0.2259 - loss: 62.0292 - val_accuracy: 0.2065 - val_loss: 66.6448 - learning_rate: 0.0010
# Epoch 9/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.2289 - loss: 140.4917
# Epoch 9: val_accuracy improved from 0.20655 to 0.31450, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 87s 595ms/step - accuracy: 0.2290 - loss: 139.9798 - val_accuracy: 0.3145 - val_loss: 32.9387 - learning_rate: 0.0010
# Epoch 10/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.2274 - loss: 46.8405
# Epoch 10: val_accuracy did not improve from 0.31450
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 73s 500ms/step - accuracy: 0.2275 - loss: 46.7610 - val_accuracy: 0.1773 - val_loss: 7.0545 - learning_rate: 0.0010
# Epoch 11/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.2343 - loss: 26.7194
# Epoch 11: val_accuracy improved from 0.31450 to 0.31839, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 97s 665ms/step - accuracy: 0.2343 - loss: 26.7066 - val_accuracy: 0.3184 - val_loss: 27.4443 - learning_rate: 0.0010
# Epoch 12/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.2628 - loss: 28.0379
# Epoch 12: val_accuracy did not improve from 0.31839
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 75s 515ms/step - accuracy: 0.2627 - loss: 28.0128 - val_accuracy: 0.2946 - val_loss: 13.8769 - learning_rate: 0.0010
# Epoch 13/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - accuracy: 0.2238 - loss: 54.4937
# Epoch 13: val_accuracy did not improve from 0.31839
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 82s 558ms/step - accuracy: 0.2238 - loss: 54.5417 - val_accuracy: 0.2373 - val_loss: 6.8395 - learning_rate: 0.0010
# Epoch 14/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.2654 - loss: 17.9467
# Epoch 14: val_accuracy improved from 0.31839 to 0.36594, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 96s 654ms/step - accuracy: 0.2654 - loss: 17.9487 - val_accuracy: 0.3659 - val_loss: 21.4673 - learning_rate: 0.0010
# Epoch 15/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.2496 - loss: 16.6524
# Epoch 15: val_accuracy did not improve from 0.36594
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 74s 504ms/step - accuracy: 0.2496 - loss: 16.6470 - val_accuracy: 0.3429 - val_loss: 7.1765 - learning_rate: 0.0010
# Epoch 16/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.2679 - loss: 22.8275
# Epoch 16: val_accuracy improved from 0.36594 to 0.39906, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 98s 669ms/step - accuracy: 0.2679 - loss: 22.8450 - val_accuracy: 0.3991 - val_loss: 8.6582 - learning_rate: 0.0010
# Epoch 17/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2763 - loss: 14.8962
# Epoch 17: val_accuracy did not improve from 0.39906
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.2763 - loss: 14.9019 - val_accuracy: 0.2857 - val_loss: 8.6798 - learning_rate: 0.0010
# Epoch 18/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - accuracy: 0.2684 - loss: 12.9634
# Epoch 18: val_accuracy did not improve from 0.39906
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 96s 655ms/step - accuracy: 0.2684 - loss: 12.9730 - val_accuracy: 0.2938 - val_loss: 9.0373 - learning_rate: 0.0010
# Epoch 19/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.2719 - loss: 12.6492
# Epoch 19: val_accuracy did not improve from 0.39906
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 85s 581ms/step - accuracy: 0.2719 - loss: 12.6513 - val_accuracy: 0.2857 - val_loss: 5.5827 - learning_rate: 0.0010
# Epoch 20/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.2722 - loss: 13.4231
# Epoch 20: val_accuracy did not improve from 0.39906
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 87s 593ms/step - accuracy: 0.2723 - loss: 13.4195 - val_accuracy: 0.2342 - val_loss: 5.9056 - learning_rate: 0.0010
# Epoch 21/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.2842 - loss: 11.3259
# Epoch 21: val_accuracy did not improve from 0.39906
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 84s 572ms/step - accuracy: 0.2842 - loss: 11.3377 - val_accuracy: 0.2666 - val_loss: 7.3669 - learning_rate: 0.0010
# Epoch 22/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - accuracy: 0.2849 - loss: 10.5308
# Epoch 22: val_accuracy did not improve from 0.39906
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 90s 613ms/step - accuracy: 0.2849 - loss: 10.5258 - val_accuracy: 0.2065 - val_loss: 16.6210 - learning_rate: 0.0010
# Epoch 23/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.2863 - loss: 12.5922
# Epoch 23: val_accuracy did not improve from 0.39906
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 82s 561ms/step - accuracy: 0.2864 - loss: 12.5834 - val_accuracy: 0.1867 - val_loss: 12.2453 - learning_rate: 0.0010
# Epoch 24/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.3260 - loss: 10.2339
# Epoch 24: val_accuracy did not improve from 0.39906
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 83s 566ms/step - accuracy: 0.3259 - loss: 10.2333 - val_accuracy: 0.2806 - val_loss: 6.7672 - learning_rate: 0.0010
# Epoch 25/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 0.2967 - loss: 8.7269
# Epoch 25: val_accuracy did not improve from 0.39906
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 91s 626ms/step - accuracy: 0.2967 - loss: 8.7302 - val_accuracy: 0.2677 - val_loss: 8.3887 - learning_rate: 0.0010
# Epoch 26/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.3008 - loss: 9.9516
# Epoch 26: val_accuracy improved from 0.39906 to 0.40023, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 100s 682ms/step - accuracy: 0.3007 - loss: 9.9576 - val_accuracy: 0.4002 - val_loss: 9.1231 - learning_rate: 0.0010
# Epoch 27/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 688ms/step - accuracy: 0.2912 - loss: 10.4254
# Epoch 27: val_accuracy did not improve from 0.40023
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 101s 693ms/step - accuracy: 0.2912 - loss: 10.4220 - val_accuracy: 0.3422 - val_loss: 5.3647 - learning_rate: 0.0010
# Epoch 28/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.3082 - loss: 8.2720
# Epoch 28: val_accuracy did not improve from 0.40023
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 85s 584ms/step - accuracy: 0.3081 - loss: 8.2753 - val_accuracy: 0.1949 - val_loss: 10.0763 - learning_rate: 0.0010
# Epoch 29/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - accuracy: 0.3032 - loss: 8.9504
# Epoch 29: val_accuracy did not improve from 0.40023
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 83s 566ms/step - accuracy: 0.3033 - loss: 8.9421 - val_accuracy: 0.3585 - val_loss: 5.8928 - learning_rate: 0.0010
# Epoch 30/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.3061 - loss: 9.5530
# Epoch 30: val_accuracy did not improve from 0.40023
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 82s 560ms/step - accuracy: 0.3061 - loss: 9.5581 - val_accuracy: 0.2724 - val_loss: 6.0630 - learning_rate: 0.0010
# Epoch 31/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.2942 - loss: 16.6289
# Epoch 31: val_accuracy improved from 0.40023 to 0.41231, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 96s 657ms/step - accuracy: 0.2942 - loss: 16.6060 - val_accuracy: 0.4123 - val_loss: 3.5538 - learning_rate: 0.0010
# Epoch 32/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.3315 - loss: 9.5319
# Epoch 32: val_accuracy did not improve from 0.41231
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 106s 728ms/step - accuracy: 0.3314 - loss: 9.5222 - val_accuracy: 0.2919 - val_loss: 5.4868 - learning_rate: 0.0010
# Epoch 33/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - accuracy: 0.3224 - loss: 9.0436
# Epoch 33: val_accuracy improved from 0.41231 to 0.41348, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 103s 703ms/step - accuracy: 0.3224 - loss: 9.0411 - val_accuracy: 0.4135 - val_loss: 4.0172 - learning_rate: 0.0010
# Epoch 34/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.3420 - loss: 6.0952
# Epoch 34: val_accuracy did not improve from 0.41348
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 128s 875ms/step - accuracy: 0.3420 - loss: 6.0964 - val_accuracy: 0.3145 - val_loss: 6.5929 - learning_rate: 0.0010
# Epoch 35/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - accuracy: 0.3279 - loss: 6.7576
# Epoch 35: val_accuracy did not improve from 0.41348
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 86s 590ms/step - accuracy: 0.3280 - loss: 6.7561 - val_accuracy: 0.2849 - val_loss: 2.8065 - learning_rate: 0.0010
# Epoch 36/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.3461 - loss: 4.2904
# Epoch 36: val_accuracy did not improve from 0.41348
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 82s 562ms/step - accuracy: 0.3461 - loss: 4.2936 - val_accuracy: 0.4022 - val_loss: 4.4224 - learning_rate: 0.0010
# Epoch 37/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.3408 - loss: 6.9338
# Epoch 37: val_accuracy improved from 0.41348 to 0.41816, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 101s 694ms/step - accuracy: 0.3408 - loss: 6.9330 - val_accuracy: 0.4182 - val_loss: 4.6922 - learning_rate: 0.0010
# Epoch 38/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 913ms/step - accuracy: 0.3237 - loss: 9.7506
# Epoch 38: val_accuracy did not improve from 0.41816
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 134s 918ms/step - accuracy: 0.3238 - loss: 9.7385 - val_accuracy: 0.4158 - val_loss: 3.2422 - learning_rate: 0.0010
# Epoch 39/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.3541 - loss: 5.6022
# Epoch 39: val_accuracy did not improve from 0.41816
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 88s 600ms/step - accuracy: 0.3541 - loss: 5.6098 - val_accuracy: 0.3036 - val_loss: 2.9320 - learning_rate: 0.0010
# Epoch 40/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.3684 - loss: 3.2037
# Epoch 40: val_accuracy did not improve from 0.41816
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 81s 555ms/step - accuracy: 0.3684 - loss: 3.2060 - val_accuracy: 0.3492 - val_loss: 8.1355 - learning_rate: 0.0010
# Epoch 41/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.3563 - loss: 7.9566
# Epoch 41: val_accuracy did not improve from 0.41816
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 87s 597ms/step - accuracy: 0.3563 - loss: 7.9489 - val_accuracy: 0.3761 - val_loss: 4.4441 - learning_rate: 0.0010
# Epoch 42/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 643ms/step - accuracy: 0.3627 - loss: 5.7672
# Epoch 42: val_accuracy did not improve from 0.41816
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 95s 648ms/step - accuracy: 0.3626 - loss: 5.7789 - val_accuracy: 0.2923 - val_loss: 6.1842 - learning_rate: 0.0010
# Epoch 43/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.3540 - loss: 4.1571
# Epoch 43: val_accuracy did not improve from 0.41816
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 85s 583ms/step - accuracy: 0.3540 - loss: 4.1617 - val_accuracy: 0.3106 - val_loss: 5.6133 - learning_rate: 0.0010
# Epoch 44/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.3328 - loss: 7.5050
# Epoch 44: val_accuracy did not improve from 0.41816
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 88s 603ms/step - accuracy: 0.3328 - loss: 7.5050 - val_accuracy: 0.3928 - val_loss: 5.0308 - learning_rate: 0.0010
# Epoch 45/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.3490 - loss: 5.5909
# Epoch 45: val_accuracy improved from 0.41816 to 0.44388, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 98s 668ms/step - accuracy: 0.3490 - loss: 5.6019 - val_accuracy: 0.4439 - val_loss: 3.9232 - learning_rate: 0.0010
# Epoch 46/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.3238 - loss: 8.1586
# Epoch 46: val_accuracy improved from 0.44388 to 0.44700, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 144s 987ms/step - accuracy: 0.3238 - loss: 8.1689 - val_accuracy: 0.4470 - val_loss: 4.4223 - learning_rate: 0.0010
# Epoch 47/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3009 - loss: 17.1338
# Epoch 47: val_accuracy did not improve from 0.44700
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.3010 - loss: 17.1111 - val_accuracy: 0.3636 - val_loss: 3.5022 - learning_rate: 0.0010
# Epoch 48/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.3493 - loss: 6.4018
# Epoch 48: val_accuracy did not improve from 0.44700
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 90s 617ms/step - accuracy: 0.3492 - loss: 6.3994 - val_accuracy: 0.4100 - val_loss: 3.1342 - learning_rate: 0.0010
# Epoch 49/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 626ms/step - accuracy: 0.3429 - loss: 10.1212
# Epoch 49: val_accuracy did not improve from 0.44700
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 92s 632ms/step - accuracy: 0.3430 - loss: 10.1031 - val_accuracy: 0.3831 - val_loss: 2.9989 - learning_rate: 0.0010
# Epoch 50/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.3602 - loss: 9.1331
# Epoch 50: val_accuracy did not improve from 0.44700
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 84s 577ms/step - accuracy: 0.3602 - loss: 9.1332 - val_accuracy: 0.4026 - val_loss: 5.9578 - learning_rate: 0.0010
# Epoch 51/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.3515 - loss: 10.6708
# Epoch 51: val_accuracy did not improve from 0.44700
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 84s 576ms/step - accuracy: 0.3515 - loss: 10.6862 - val_accuracy: 0.2592 - val_loss: 5.8940 - learning_rate: 0.0010
# Epoch 52/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.3622 - loss: 7.4233
# Epoch 52: val_accuracy did not improve from 0.44700
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 82s 563ms/step - accuracy: 0.3623 - loss: 7.4080 - val_accuracy: 0.3932 - val_loss: 2.3531 - learning_rate: 0.0010
# Epoch 53/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.3819 - loss: 5.3062
# Epoch 53: val_accuracy did not improve from 0.44700
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 83s 568ms/step - accuracy: 0.3819 - loss: 5.3008 - val_accuracy: 0.3815 - val_loss: 3.2348 - learning_rate: 0.0010
# Epoch 54/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.3773 - loss: 6.0270
# Epoch 54: val_accuracy did not improve from 0.44700
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 86s 585ms/step - accuracy: 0.3774 - loss: 6.0196 - val_accuracy: 0.4310 - val_loss: 3.1201 - learning_rate: 0.0010
# Epoch 55/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.3794 - loss: 4.2843
# Epoch 55: val_accuracy did not improve from 0.44700
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 85s 584ms/step - accuracy: 0.3794 - loss: 4.2854 - val_accuracy: 0.2603 - val_loss: 7.4700 - learning_rate: 0.0010
# Epoch 56/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.3506 - loss: 6.1241
# Epoch 56: val_accuracy did not improve from 0.44700
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 83s 567ms/step - accuracy: 0.3507 - loss: 6.1211 - val_accuracy: 0.3012 - val_loss: 3.1290 - learning_rate: 0.0010
# Epoch 57/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.4851 - loss: 1.7623
# Epoch 57: val_accuracy improved from 0.44700 to 0.51832, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 96s 655ms/step - accuracy: 0.4853 - loss: 1.7606 - val_accuracy: 0.5183 - val_loss: 1.4560 - learning_rate: 1.0000e-04
# Epoch 58/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.5369 - loss: 1.3499
# Epoch 58: val_accuracy improved from 0.51832 to 0.53118, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 142s 971ms/step - accuracy: 0.5369 - loss: 1.3499 - val_accuracy: 0.5312 - val_loss: 1.4633 - learning_rate: 1.0000e-04
# Epoch 59/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5431 - loss: 1.3206
# Epoch 59: val_accuracy did not improve from 0.53118
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.5431 - loss: 1.3207 - val_accuracy: 0.5226 - val_loss: 1.5252 - learning_rate: 1.0000e-04
# Epoch 60/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 0.5528 - loss: 1.3101
# Epoch 60: val_accuracy improved from 0.53118 to 0.53780, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 106s 723ms/step - accuracy: 0.5528 - loss: 1.3101 - val_accuracy: 0.5378 - val_loss: 1.4611 - learning_rate: 1.0000e-04
# Epoch 61/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 989ms/step - accuracy: 0.5475 - loss: 1.2851
# Epoch 61: val_accuracy did not improve from 0.53780
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 145s 994ms/step - accuracy: 0.5475 - loss: 1.2852 - val_accuracy: 0.5284 - val_loss: 1.5867 - learning_rate: 1.0000e-04
# Epoch 62/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.5548 - loss: 1.2843
# Epoch 62: val_accuracy improved from 0.53780 to 0.54404, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 101s 693ms/step - accuracy: 0.5548 - loss: 1.2842 - val_accuracy: 0.5440 - val_loss: 1.5069 - learning_rate: 1.0000e-04
# Epoch 63/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5715 - loss: 1.2495
# Epoch 63: val_accuracy improved from 0.54404 to 0.54638, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.5715 - loss: 1.2495 - val_accuracy: 0.5464 - val_loss: 1.5402 - learning_rate: 1.0000e-04
# Epoch 64/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 906ms/step - accuracy: 0.5723 - loss: 1.2380
# Epoch 64: val_accuracy did not improve from 0.54638
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 133s 912ms/step - accuracy: 0.5723 - loss: 1.2380 - val_accuracy: 0.5246 - val_loss: 1.5821 - learning_rate: 1.0000e-04
# Epoch 65/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.5747 - loss: 1.2278
# Epoch 65: val_accuracy improved from 0.54638 to 0.55105, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 98s 672ms/step - accuracy: 0.5747 - loss: 1.2279 - val_accuracy: 0.5511 - val_loss: 1.5060 - learning_rate: 1.0000e-04
# Epoch 66/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5856 - loss: 1.1979
# Epoch 66: val_accuracy improved from 0.55105 to 0.55378, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.5855 - loss: 1.1980 - val_accuracy: 0.5538 - val_loss: 1.5414 - learning_rate: 1.0000e-04
# Epoch 67/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.5785 - loss: 1.1991
# Epoch 67: val_accuracy did not improve from 0.55378
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 103s 702ms/step - accuracy: 0.5785 - loss: 1.1991 - val_accuracy: 0.5511 - val_loss: 1.4586 - learning_rate: 1.0000e-04
# Epoch 68/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.5920 - loss: 1.1956
# Epoch 68: val_accuracy improved from 0.55378 to 0.56041, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 99s 675ms/step - accuracy: 0.5919 - loss: 1.1956 - val_accuracy: 0.5604 - val_loss: 1.5094 - learning_rate: 1.0000e-04
# Epoch 69/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 719ms/step - accuracy: 0.5856 - loss: 1.1865
# Epoch 69: val_accuracy improved from 0.56041 to 0.56235, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 119s 814ms/step - accuracy: 0.5856 - loss: 1.1864 - val_accuracy: 0.5624 - val_loss: 1.4568 - learning_rate: 1.0000e-04
# Epoch 70/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.5905 - loss: 1.1698
# Epoch 70: val_accuracy did not improve from 0.56235
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 80s 546ms/step - accuracy: 0.5905 - loss: 1.1699 - val_accuracy: 0.5401 - val_loss: 1.4933 - learning_rate: 1.0000e-04
# Epoch 71/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.6013 - loss: 1.1334
# Epoch 71: val_accuracy did not improve from 0.56235
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 82s 564ms/step - accuracy: 0.6013 - loss: 1.1335 - val_accuracy: 0.5616 - val_loss: 1.5180 - learning_rate: 1.0000e-04
# Epoch 72/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.6080 - loss: 1.1398
# Epoch 72: val_accuracy did not improve from 0.56235
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 82s 561ms/step - accuracy: 0.6080 - loss: 1.1398 - val_accuracy: 0.5557 - val_loss: 1.5077 - learning_rate: 1.0000e-04
# Epoch 73/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.6087 - loss: 1.1244
# Epoch 73: val_accuracy did not improve from 0.56235
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 83s 567ms/step - accuracy: 0.6087 - loss: 1.1244 - val_accuracy: 0.5409 - val_loss: 1.6002 - learning_rate: 1.0000e-04
# Epoch 74/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.6113 - loss: 1.1130
# Epoch 74: val_accuracy did not improve from 0.56235
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 83s 567ms/step - accuracy: 0.6113 - loss: 1.1129 - val_accuracy: 0.5565 - val_loss: 1.6006 - learning_rate: 1.0000e-04
# Epoch 75/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.6227 - loss: 1.0847
# Epoch 75: val_accuracy did not improve from 0.56235
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 88s 598ms/step - accuracy: 0.6226 - loss: 1.0848 - val_accuracy: 0.5526 - val_loss: 1.5407 - learning_rate: 1.0000e-04
# Epoch 76/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.6204 - loss: 1.0857
# Epoch 76: val_accuracy did not improve from 0.56235
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 82s 564ms/step - accuracy: 0.6203 - loss: 1.0858 - val_accuracy: 0.5585 - val_loss: 1.5003 - learning_rate: 1.0000e-04
# Epoch 77/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.6266 - loss: 1.0697
# Epoch 77: val_accuracy did not improve from 0.56235
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 82s 563ms/step - accuracy: 0.6266 - loss: 1.0697 - val_accuracy: 0.5592 - val_loss: 1.5751 - learning_rate: 1.0000e-04
# Epoch 78/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.6261 - loss: 1.0806
# Epoch 78: val_accuracy improved from 0.56235 to 0.57288, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 96s 660ms/step - accuracy: 0.6261 - loss: 1.0806 - val_accuracy: 0.5729 - val_loss: 1.5260 - learning_rate: 1.0000e-04
# Epoch 79/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.6298 - loss: 1.0631
# Epoch 79: val_accuracy did not improve from 0.57288
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 78s 533ms/step - accuracy: 0.6298 - loss: 1.0631 - val_accuracy: 0.5635 - val_loss: 1.5590 - learning_rate: 1.0000e-04
# Epoch 80/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - accuracy: 0.6337 - loss: 1.0330
# Epoch 80: val_accuracy did not improve from 0.57288
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 83s 570ms/step - accuracy: 0.6337 - loss: 1.0330 - val_accuracy: 0.5468 - val_loss: 1.5726 - learning_rate: 1.0000e-04
# Epoch 81/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.6435 - loss: 1.0366
# Epoch 81: val_accuracy did not improve from 0.57288
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 83s 568ms/step - accuracy: 0.6434 - loss: 1.0366 - val_accuracy: 0.5659 - val_loss: 1.6434 - learning_rate: 1.0000e-04
# Epoch 82/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.6416 - loss: 1.0131
# Epoch 82: val_accuracy improved from 0.57288 to 0.57677, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 95s 647ms/step - accuracy: 0.6416 - loss: 1.0131 - val_accuracy: 0.5768 - val_loss: 1.6321 - learning_rate: 1.0000e-04
# Epoch 83/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.6489 - loss: 1.0014
# Epoch 83: val_accuracy did not improve from 0.57677
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 77s 527ms/step - accuracy: 0.6489 - loss: 1.0014 - val_accuracy: 0.5585 - val_loss: 1.6872 - learning_rate: 1.0000e-04
# Epoch 84/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - accuracy: 0.6628 - loss: 0.9748
# Epoch 84: val_accuracy did not improve from 0.57677
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 82s 558ms/step - accuracy: 0.6628 - loss: 0.9749 - val_accuracy: 0.5456 - val_loss: 1.6769 - learning_rate: 1.0000e-04
# Epoch 85/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 632ms/step - accuracy: 0.6549 - loss: 0.9995
# Epoch 85: val_accuracy improved from 0.57677 to 0.57989, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 106s 728ms/step - accuracy: 0.6549 - loss: 0.9995 - val_accuracy: 0.5799 - val_loss: 1.5674 - learning_rate: 1.0000e-04
# Epoch 86/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.6675 - loss: 0.9453
# Epoch 86: val_accuracy did not improve from 0.57989
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 73s 496ms/step - accuracy: 0.6675 - loss: 0.9454 - val_accuracy: 0.5577 - val_loss: 1.7042 - learning_rate: 1.0000e-04
# Epoch 87/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.6654 - loss: 0.9696
# Epoch 87: val_accuracy did not improve from 0.57989
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 81s 557ms/step - accuracy: 0.6655 - loss: 0.9695 - val_accuracy: 0.5709 - val_loss: 1.6561 - learning_rate: 1.0000e-04
# Epoch 88/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.6763 - loss: 0.9343
# Epoch 88: val_accuracy improved from 0.57989 to 0.58106, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 95s 649ms/step - accuracy: 0.6762 - loss: 0.9344 - val_accuracy: 0.5811 - val_loss: 1.6948 - learning_rate: 1.0000e-04
# Epoch 89/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.6803 - loss: 0.9096
# Epoch 89: val_accuracy did not improve from 0.58106
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 84s 573ms/step - accuracy: 0.6803 - loss: 0.9097 - val_accuracy: 0.5651 - val_loss: 1.7905 - learning_rate: 1.0000e-04
# Epoch 90/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.6919 - loss: 0.8823
# Epoch 90: val_accuracy improved from 0.58106 to 0.58340, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 95s 649ms/step - accuracy: 0.6919 - loss: 0.8823 - val_accuracy: 0.5834 - val_loss: 1.6835 - learning_rate: 1.0000e-04
# Epoch 91/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.6872 - loss: 0.8795
# Epoch 91: val_accuracy improved from 0.58340 to 0.58574, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 108s 739ms/step - accuracy: 0.6872 - loss: 0.8795 - val_accuracy: 0.5857 - val_loss: 1.7361 - learning_rate: 1.0000e-04
# Epoch 92/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.6980 - loss: 0.8578
# Epoch 92: val_accuracy did not improve from 0.58574
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 98s 670ms/step - accuracy: 0.6980 - loss: 0.8580 - val_accuracy: 0.5682 - val_loss: 1.7321 - learning_rate: 1.0000e-04
# Epoch 93/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.6982 - loss: 0.8588
# Epoch 93: val_accuracy did not improve from 0.58574
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 86s 587ms/step - accuracy: 0.6982 - loss: 0.8588 - val_accuracy: 0.5853 - val_loss: 1.8657 - learning_rate: 1.0000e-04
# Epoch 94/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.7037 - loss: 0.8507
# Epoch 94: val_accuracy did not improve from 0.58574
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 94s 642ms/step - accuracy: 0.7036 - loss: 0.8507 - val_accuracy: 0.5826 - val_loss: 1.6972 - learning_rate: 1.0000e-04
# Epoch 95/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 0.7013 - loss: 0.8384
# Epoch 95: val_accuracy did not improve from 0.58574
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 96s 655ms/step - accuracy: 0.7013 - loss: 0.8384 - val_accuracy: 0.5764 - val_loss: 1.7458 - learning_rate: 1.0000e-04
# Epoch 96/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.7061 - loss: 0.8368
# Epoch 96: val_accuracy did not improve from 0.58574
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 98s 672ms/step - accuracy: 0.7061 - loss: 0.8367 - val_accuracy: 0.5807 - val_loss: 1.7966 - learning_rate: 1.0000e-04
# Epoch 97/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 629ms/step - accuracy: 0.7148 - loss: 0.8036
# Epoch 97: val_accuracy improved from 0.58574 to 0.58807, saving model to model.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 106s 727ms/step - accuracy: 0.7148 - loss: 0.8037 - val_accuracy: 0.5881 - val_loss: 1.7965 - learning_rate: 1.0000e-04
# Epoch 98/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.7243 - loss: 0.7920
# Epoch 98: val_accuracy did not improve from 0.58807
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 109s 745ms/step - accuracy: 0.7243 - loss: 0.7921 - val_accuracy: 0.5678 - val_loss: 1.7313 - learning_rate: 1.0000e-04
# Epoch 99/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - accuracy: 0.7294 - loss: 0.7838
# Epoch 99: val_accuracy did not improve from 0.58807
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 109s 744ms/step - accuracy: 0.7293 - loss: 0.7838 - val_accuracy: 0.5795 - val_loss: 1.8565 - learning_rate: 1.0000e-04
# Epoch 100/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 769ms/step - accuracy: 0.7286 - loss: 0.7771
# Epoch 100: val_accuracy did not improve from 0.58807
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 113s 774ms/step - accuracy: 0.7286 - loss: 0.7771 - val_accuracy: 0.5811 - val_loss: 1.8649 - learning_rate: 1.0000e-04
# Best validation model: epoch 97  - val_accuracy 0.588074803352356

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show(fig)

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)
results = h.history

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 10))

# Plot Accuracy
axes[0].plot(results["accuracy"], label="Training Accuracy", color="blue")
axes[0].plot(results["val_accuracy"], label="Validation Accuracy", color="green")
axes[0].set_ylabel("Accuracy")
axes[0].set_title("Accuracy Over Epochs")
axes[0].legend()
axes[0].grid(True)
axes[0].set_ylim(0, 1)  # Normalize y-axis for accuracy (0-1 range)

# Plot Loss
axes[1].plot(results["loss"], label="Training Loss", color="red")
axes[1].plot(results["val_loss"], label="Validation Loss", color="orange")
axes[1].set_ylabel("Loss")
axes[1].set_title("Loss Over Epochs")
axes[1].legend()
axes[1].grid(True)
axes[1].set_ylim(0, max(max(results["loss"]), max(results["val_loss"])) * 1.1)  # Normalize loss y-axis

plt.xlabel("Epochs")
plt.tight_layout()

plt.savefig("/kaggle/working/plot.png", format="png", bbox_inches="tight")
plt.close()
# Out:
# <ipython-input-15-39df9ea0fe34>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 58.807%
# Mean Recall: 50.465%
# Mean Precision: 52.657%
# > Cargo plane: Recall: 63.158% Precision: 84.211% Specificity: 99.639% Dice: 72.180%
# > Helicopter: Recall: 25.000% Precision: 16.667% Specificity: 99.609% Dice: 20.000%
# > Small car: Recall: 79.806% Precision: 73.002% Specificity: 92.589% Dice: 76.252%
# > Bus: Recall: 50.965% Precision: 50.000% Specificity: 94.278% Dice: 50.478%
# > Truck: Recall: 23.030% Precision: 38.974% Specificity: 94.678% Dice: 28.952%
# > Motorboat: Recall: 43.750% Precision: 50.909% Specificity: 97.785% Dice: 47.059%
# > Fishing vessel: Recall: 41.176% Precision: 40.230% Specificity: 97.904% Dice: 40.698%
# > Dump truck: Recall: 43.919% Precision: 52.419% Specificity: 97.560% Dice: 47.794%
# > Excavator: Recall: 67.368% Precision: 48.485% Specificity: 97.248% Dice: 56.388%
# > Building: Recall: 83.126% Precision: 62.735% Specificity: 86.121% Dice: 71.505%
# > Storage tank: Recall: 31.818% Precision: 62.921% Specificity: 98.619% Dice: 42.264%
# > Shipping container: Recall: 52.459% Precision: 51.337% Specificity: 96.181% Dice: 51.892%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/deeplearning/xview_recognition/xview_test'):
    for filename in filenames:
        image = GenericImage('xview_test/'+filename)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2635

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("/kaggle/working/prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
